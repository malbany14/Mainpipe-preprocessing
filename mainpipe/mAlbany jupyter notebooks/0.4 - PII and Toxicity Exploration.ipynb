# %%
import json
import pandas as pd
import matplotlib as mp
# for language detection
from presidio_analyzer import AnalyzerEngine, RecognizerResult
import pandas as pd
import spacy
import re

# %%
filepath = "../../data/cleaned/cleaned_csv_test.JSONL"
data = []

with open(filepath, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            data.append(json.loads(line))
        except json.JSONDecodeError:
            continue

df = pd.DataFrame(data)
print(df)
# Out:
#         doc_id                                               text  \
# 0            0  bernadine brings to the agency over twenty yea...
# 1            1  a cute denim skirt by dickies!\npair this jean...
# 2            2  see the latest foothills homes february 2016 r...
# 3            4  shape of the world is stu maxwell's passion pr...
# 4            5  function dunfile(startcoord, rawpillardata, du...
# ...        ...                                                ...
# 197785  220743  and it was not "free to threaten". it was unde...
# 197786  220744  catch up on business tips at bizbarcelona as t...
# 197787  220745  problem i have is trying to figure out whether...
# 197788  220746  i don't know why anybody's gonna get their pan...
# 197789  220748  what is a tool or technique that can be used t...
#
#                                                       url  element_count  \
# 0       https://www.4rfv.com/V7BTWGJ6BUYI/AA/bernadine...              0
# 1       http://www.uk-beaders.co.uk/dickies-denim-skir...              0
# 2       https://www.premiertucsonhomes.com/foothills-h...              0
# 3       https://killscreen.com/articles/shape-world-wa...              0
# 4       https://github.com/doggan/diablo-file-formats/...              0
# ...                                                   ...            ...
# 197785                                               None              0
# 197786  https://www.barcelona-metropolitan.com/events/...              0
# 197787                                               None              0
# 197788                                               None              0
# 197789                                               None              0
#
#         non-utf8_count language
# 0                    0       en
# 1                    0       en
# 2                    0       en
# 3                    0       en
# 4                    0       en
# ...                ...      ...
# 197785               0       en
# 197786               0       en
# 197787               0       en
# 197788               0       en
# 197789               0       en
#
# [197790 rows x 6 columns]

# %%
df
# Out:
#         doc_id                                               text  \
# 0            0  bernadine brings to the agency over twenty yea...
# 1            1  a cute denim skirt by dickies!\npair this jean...
# 2            2  see the latest foothills homes february 2016 r...
# 3            4  shape of the world is stu maxwell's passion pr...
# 4            5  function dunfile(startcoord, rawpillardata, du...
# ...        ...                                                ...
# 197785  220743  and it was not "free to threaten". it was unde...
# 197786  220744  catch up on business tips at bizbarcelona as t...
# 197787  220745  problem i have is trying to figure out whether...
# 197788  220746  i don't know why anybody's gonna get their pan...
# 197789  220748  what is a tool or technique that can be used t...
#
#                                                       url  element_count  \
# 0       https://www.4rfv.com/V7BTWGJ6BUYI/AA/bernadine...              0
# 1       http://www.uk-beaders.co.uk/dickies-denim-skir...              0
# 2       https://www.premiertucsonhomes.com/foothills-h...              0
# 3       https://killscreen.com/articles/shape-world-wa...              0
# 4       https://github.com/doggan/diablo-file-formats/...              0
# ...                                                   ...            ...
# 197785                                               None              0
# 197786  https://www.barcelona-metropolitan.com/events/...              0
# 197787                                               None              0
# 197788                                               None              0
# 197789                                               None              0
#
#         non-utf8_count language
# 0                    0       en
# 1                    0       en
# 2                    0       en
# 3                    0       en
# 4                    0       en
# ...                ...      ...
# 197785               0       en
# 197786               0       en
# 197787               0       en
# 197788               0       en
# 197789               0       en
#
# [197790 rows x 6 columns]

# %%
# REduce df size for analysis
df = df[:2500]

# %% [markdown]
# # PII counts

# %%
analyzer = AnalyzerEngine()

# %%
def count_pii(text):
    """
    Count PII entities in a single text string using Presidio.
    Returns (total_hits, entity_counts_dict)
    """
    if not isinstance(text, str) or not text.strip():
        return 0, {}

    # Analyze text for common PII entities
    results = analyzer.analyze(
        text=text,
        entities=["EMAIL_ADDRESS", "PHONE_NUMBER"],
        language="en"
    )

    # Count occurrences
    total_hits = len(results)
    entity_counts = {}
    for r in results:
        entity_counts[r.entity_type] = entity_counts.get(r.entity_type, 0) + 1

    return total_hits, entity_counts

# %%
df["pii_results"] = df["text"].apply(count_pii)
df["pii_count"] = df["pii_results"].apply(lambda x: x[0])
df["pii_breakdown"] = df["pii_results"].apply(lambda x: x[1])
df = df.drop(columns="pii_results")

# %%
df.head(50)
# Out:
#     doc_id                                               text  \
# 0        0  bernadine brings to the agency over twenty yea...
# 1        1  a cute denim skirt by dickies!\npair this jean...
# 2        2  see the latest foothills homes february 2016 r...
# 3        4  shape of the world is stu maxwell's passion pr...
# 4        5  function dunfile(startcoord, rawpillardata, du...
# 5        6  we offer a number of products.\nwhen purchasin...
# 6        7  def example_lab_to_rgb():\n    """\n    conver...
# 7        8  nowadays the most important protection element...
# 8       10  def select_host(self, metric):\n        """\n ...
# 9       11  welcome to my travel blog. my name is james fr...
# 10      13  home\nabout\ncontact information\nread our lat...
# 11      14  i have a site using a custom favicon.ico. the ...
# 12      15  blog post\nread our latest blog posts and indu...
# 13      16  """\n    timeout = kwargs.get('timeout', none)...
# 14      17  assert isinstance(node, symbolargument) or isi...
# 15      18  function getmarkdownitanchorid (text) {\n  tex...
# 16      19  how was it uncivil? pointing out that trump lo...
# 17      20  function() {\n          if(angular.isarray(sel...
# 18      21  "this is the senate's best proposal at this ti...
# 19      22  i just did a fairly significant hardware upgra...
# 20      23  as i mention in an earlier question, i'm refac...
# 21      24  create a worker type.  a worker type contains ...
# 22      25  . . ❤️) . .\nhappy to be a member of ffu!\nsma...
# 23      26  function language(node) {\n  var classname = n...
# 24      27  i want to be able to get an estimate of how mu...
# 25      28  wang chu studies computer science at one of be...
# 26      29  # add n column, listing total non-null values ...
# 27      30  my custom homebrew photography processing soft...
# 28      31  we provide high-quality products and excellent...
# 29      32  fitz' could face sideline ban fitz' could face...
# 30      33  thanks for the recognition. there are so many ...
# 31      34  there are 313.89 miles from wembley to water v...
# 32      35  john, quit spewing misinformation. you write "...
# 33      36  chris, i think the number is on the rise.  of ...
# 34      37  here is a movie that should have been here 5 y...
# 35      38  if you need local support to find partners or ...
# 36      39  pretty simple: i need a way to convert special...
# 37      40  italian election campaign thrives on trash tal...
# 38      41  my how the mighty have fallen. from one of the...
# 39      42  spot on. you just nailed a few of the worst pe...
# 40      43  treasury market outlook: bond yields are cheap...
# 41      44  new york (cbsnewyork) — police released survei...
# 42      45  i have a dell dimension 9200, and am using an ...
# 43      46  def __create_rec(*args, **kwargs):\n        ''...
# 44      47  these little beauties feature the symbolic ham...
# 45      48  get over it, so-called patriot.  you probably ...
# 46      49  i have a couple of pages, each has around 20 l...
# 47      50  i have xp pro sp3.\ni have boot management sof...
# 48      51  they will consider him - in 8 months if the ne...
# 49      52  # are we waiting for the processor to complete...
#
#                                                   url  element_count  \
# 0   https://www.4rfv.com/V7BTWGJ6BUYI/AA/bernadine...              0
# 1   http://www.uk-beaders.co.uk/dickies-denim-skir...              0
# 2   https://www.premiertucsonhomes.com/foothills-h...              0
# 3   https://killscreen.com/articles/shape-world-wa...              0
# 4   https://github.com/doggan/diablo-file-formats/...              0
# 5             http://lendsense.com/mortgage-products/              0
# 6   https://github.com/gtaylor/python-colormath/bl...              0
# 7         http://cybersecurity.mk/services/consulting              0
# 8   https://github.com/brutasse/graphite-api/blob/...              0
# 9                  https://www.jamesfrazermann.co.uk/              0
# 10                 https://demo-page.info/page72.html              0
# 11                                               None              3
# 12                   https://testsite.org/page66.html              0
# 13  https://github.com/ska-sa/katcp-python/blob/91...              0
# 14  https://github.com/boriel/zxbasic/blob/23b28db...              0
# 15  https://github.com/commenthol/markedpp/blob/f7...              0
# 16                                               None              0
# 17  https://github.com/jtrussell/angular-selection...              0
# 18                                               None              0
# 19                                               None              0
# 20                                               None              0
# 21  https://github.com/taskcluster/taskcluster-cli...              0
# 22  https://www.fairylandgame.com/fbfairy/fairygar...              0
# 23  https://github.com/rehypejs/rehype-highlight/b...              0
# 24                                               None              0
# 25               https://www.beijingsmog.net/projects              0
# 26  https://github.com/tompollard/tableone/blob/4a...              0
# 27                                               None              0
# 28                    https://example.com/page48.html              0
# 29  http://www.hoganstand.com/ArticleForm.aspx?ID=...              0
# 30  https://productioncommunity.publicmobile.ca/t5...              0
# 31  https://www.distance-cities.com/ca/distance-we...              0
# 32                                               None              0
# 33                                               None              0
# 34      https://www.newgrounds.com/portal/view/527209              0
# 35  https://partners.sigfox.com/companies/sigfox-o...              0
# 36                                               None              1
# 37      https://www.taiwannews.com.tw/en/news/3353844              0
# 38                                               None              0
# 39                                               None              0
# 40  https://thefly.com/landingPageNews.php?id=2893...              0
# 41  http://newyork.cbslocal.com/2018/03/19/coney-i...              0
# 42                                               None              0
# 43  https://github.com/bukun/TorCMS/blob/6567c7fe2...              0
# 44    https://www.dandelionsonline.com/products/hamsa              0
# 45                                               None              0
# 46                                               None              0
# 47                                               None              0
# 48                                               None              0
# 49  https://github.com/ciena/afkak/blob/6f5e05ba6f...              0
#
#     non-utf8_count language  pii_count pii_breakdown
# 0                0       en          0            {}
# 1                0       en          0            {}
# 2                0       en          0            {}
# 3                0       en          0            {}
# 4                0       en          0            {}
# 5                0       en          0            {}
# 6                0       en          0            {}
# 7                0       en          0            {}
# 8                0       en          0            {}
# 9                0       en          0            {}
# 10               0       en          0            {}
# 11               0       en          0            {}
# 12               0       en          0            {}
# 13               0       en          0            {}
# 14               0       en          0            {}
# 15               0       en          0            {}
# 16               0       en          0            {}
# 17               0       en          0            {}
# 18               0       en          0            {}
# 19               0       en          0            {}
# 20               0       en          0            {}
# 21               0       en          0            {}
# 22               0       en          0            {}
# 23               0       en          0            {}
# 24               0       en          0            {}
# 25               0       en          0            {}
# 26               0       en          0            {}
# 27               0       en          0            {}
# 28               0       en          0            {}
# 29               0       en          0            {}
# 30               0       en          0            {}
# 31               0       en          0            {}
# 32               0       en          0            {}
# 33               0       en          0            {}
# 34               0       en          0            {}
# 35               0       en          0            {}
# 36               0       en          0            {}
# 37               0       en          0            {}
# 38               0       en          0            {}
# 39               0       en          0            {}
# 40               0       en          0            {}
# 41               0       en          0            {}
# 42               0       en          0            {}
# 43               0       en          0            {}
# 44               0       en          0            {}
# 45               0       en          0            {}
# 46               0       en          0            {}
# 47               0       en          0            {}
# 48               0       en          0            {}
# 49               0       en          0            {}

# %% [markdown]
# # spacey

# %%
nlp = spacy.load("en_core_web_lg")

# %%
def count_pii_spacy(text):
    doc = nlp(text)
    
    entity_counts = {}
    total_hits = 0

    # Named Entity Recognition (NER) from spaCy
    for ent in doc.ents:
        if ent.label_ in ["PERSON"]:  # Common PII-related entities
            entity_counts[ent.label_] = entity_counts.get(ent.label_, 0) + 1
            total_hits += 1

    # Regex patterns for things spaCy misses (emails, phones, SSNs)
    patterns = {
        "EMAIL": r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b",
        "PHONE": r"\b(?:\+?61|0)[2-478](?:[ -]?\d){8}\b",
    }

    for label, pattern in patterns.items():
        matches = re.findall(pattern, text)
        if matches:
            entity_counts[label] = len(matches)
            total_hits += len(matches)
    
    return total_hits, entity_counts

# %%
df["pii_results"] = df["text"].apply(count_pii_spacy)
df["pii_count"] = df["pii_results"].apply(lambda x: x[0])
df["pii_breakdown"] = df["pii_results"].apply(lambda x: x[1])
df = df.drop(columns="pii_results")

# %%
df.iloc[0]
# Out:
# doc_id                                                            0
# text              bernadine brings to the agency over twenty yea...
# url               https://www.4rfv.com/V7BTWGJ6BUYI/AA/bernadine...
# element_count                                                     0
# non-utf8_count                                                    0
# language                                                         en
# pii_count                                                        33
# pii_breakdown        {'PERSON': 8, 'ORG': 12, 'GPE': 12, 'NORP': 1}
# Name: 0, dtype: object

# %% [markdown]
# # Regex PII

# %%
def mask_text(text):
    phone = re.compile(r'\b(?:\+?61|0)[2-478](?:[ -]?\d){8}\b')
    email = re.compile(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b')
    tfn = re.compile(r'\b\d{3}\s?\d{3}\s?\d{3}\b')

    masked_items = []

    if re.search(email, text):
        text = re.sub(email, "[EMAIL_MASKED]", text)
        masked_items.append("email")

    if re.search(phone, text):
        text = re.sub(phone, "[PHONE_MASKED]", text)
        masked_items.append("phone")

    if re.search(tfn, text):
        text = re.sub(tfn, "[TFN_MASKED]", text)
        masked_items.append("tfn")

    return text, ", ".join(masked_items) if masked_items else None

# %%
df[['text', 'masked_items']] = df['text'].apply(lambda x: pd.Series(mask_text(x)))

# %%
df['masked_items'].value_counts()
# Out:
# masked_items
# email           86
# tfn             16
# phone            3
# email, phone     1
# Name: count, dtype: int64

# %%
emails = df[df['masked_items'] == 'email']
emails['text'].iloc[0]
# Out:
# 'is there a way to create a direct link to a file on an internal network share on mac os x. in windows you can do this with file://filepath, but i can\'t find a solution that works on mac\nthank you\ngmail has a very nice ability to check for your pop accounts and send email through your own smtp settings. it will however always show something like "from:[EMAIL_MASKED] as [EMAIL_MASKED]" in the header of some more advanced email clients (like outlook).\nif you can handle setting up your own email server, go for it, but it will be hard and costly to achieve the same uptime and quality of service gmail does. if you have your own domain, i highly recommend using the google apps service so you get the quality of gmail, but with your own email address.'

# %% [markdown]
# # Toxic

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import torch.nn.functional as F
from multiprocessing import Pool, cpu_count

# --- Model setup ---
model_name = "unitary/toxic-bert"  # original Toxic-BERT
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
device = "cpu"  # CPU-only
model.to(device)
model.eval()  # important for inference

# --- Prediction function for a batch of texts ---
def predict_batch(texts):
    inputs = tokenizer(texts, return_tensors="pt", truncation=True, padding=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs)
        probs = F.softmax(outputs.logits, dim=1)
    return probs[:, 1].tolist()  # probability of toxic class

# --- Function to process batches (used in multiprocessing) ---
def process_batch(batch_texts):
    return predict_batch(batch_texts)

# --- Split data into batches ---
batch_size = 64  # adjust based on RAM
texts = df['text'].astype(str).tolist()
batches = [texts[i:i+batch_size] for i in range(0, len(texts), batch_size)]

# --- Use multiprocessing to process batches in parallel ---
num_cores = min(cpu_count(), len(batches))
with Pool(num_cores) as pool:
    results_list = pool.map(process_batch, batches)

# --- Flatten results ---
toxicity_scores = [score for batch in results_list for score in batch]
df['toxicity_score'] = toxicity_scores
df['is_toxic'] = df['toxicity_score'] >= 0.5

print("Toxic rows flagged:", df['is_toxic'].sum())

# %%
df
# Out:
#       doc_id                                               text  \
# 0          0  bernadine brings to the agency over twenty yea...
# 1          1  a cute denim skirt by dickies!\npair this jean...
# 2          2  see the latest foothills homes february 2016 r...
# 3          4  shape of the world is stu maxwell's passion pr...
# 4          5  function dunfile(startcoord, rawpillardata, du...
# ...      ...                                                ...
# 2495    2761  the sad part is the invisibility of those suff...
# 2496    2762  goat poo is a fabulous fertilizer and is  easi...
# 2497    2763  coming from a c# background the naming convent...
# 2498    2764  we have a team of highly qualified in their ro...
# 2499    2765  i am sick and tired of my widescreen 16:9 macb...
#
#                                                     url  element_count  \
# 0     https://www.4rfv.com/V7BTWGJ6BUYI/AA/bernadine...              0
# 1     http://www.uk-beaders.co.uk/dickies-denim-skir...              0
# 2     https://www.premiertucsonhomes.com/foothills-h...              0
# 3     https://killscreen.com/articles/shape-world-wa...              0
# 4     https://github.com/doggan/diablo-file-formats/...              0
# ...                                                 ...            ...
# 2495                                               None              0
# 2496                                               None              0
# 2497                                               None              0
# 2498     http://www.arab-adventures.com/about/our-team/              0
# 2499                                               None              0
#
#       non-utf8_count language  toxicity_score  is_toxic
# 0                  0       en        0.094488     False
# 1                  0       en        0.001384     False
# 2                  0       en        0.093094     False
# 3                  0       en        0.082762     False
# 4                  0       en        0.012584     False
# ...              ...      ...             ...       ...
# 2495               0       en        0.053282     False
# 2496               0       en        0.020194     False
# 2497               0       en        0.091265     False
# 2498               0       en        0.077829     False
# 2499               0       en        0.041623     False
#
# [2500 rows x 8 columns]
